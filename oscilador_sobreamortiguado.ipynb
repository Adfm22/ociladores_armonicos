# %% [markdown]
# oscilador semiamortiguado para el caso cuando \gamma << \omega ^2

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop, Adam

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
class ODEsolver(Sequential):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.loss_tracker = keras.metrics.Mean(name="loss")

    @property
    def metrics(self):
        return [self.loss_tracker]

    def train_step(self, data):
        batch_size = tf.shape(data)[0]
        x = tf.random.uniform((batch_size, 1), minval=0, maxval=3)  # Cambio de t a x, ajuste de rango de valores iniciales
        x_0 = tf.zeros((batch_size,1))
        
        with tf.GradientTape() as tape:
            # Cálculo de la pérdida y los gradientes
            with tf.GradientTape(persistent=True) as tape1:
                tape1.watch(x)
                tape1.watch(x_0)

                with tf.GradientTape() as tape2:
                    tape2.watch(x)    
                    y_pred = self(x, training=True)
                y_x = tape2.gradient(y_pred, x)
                y_0 = self(x_0, training=True)
            
            ddy = tape1.gradient(y_x, x)
            dy_x0 = tape1.gradient(y_0, x_0)
            eq = ddy + 0.1*y_x + 100*y_pred  # Ajuste de la ecuación diferencial
            ic = y_0 - 1  # Ajuste de la condición inicial y(0)
            ic1 = dy_x0  # Ajuste de la condición inicial y'(0)
            loss = keras.losses.mean_squared_error(0., eq) + keras.losses.mean_squared_error(0., ic) + keras.losses.mean_squared_error(0., ic1)

        # Aplicar gradientes
        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.trainable_variables))
        # Actualizar métricas
        self.loss_tracker.update_state(loss)
        # Devolver un diccionario que mapea nombres de métricas a valores actuales
        return {"loss": self.loss_tracker.result()}

# %%
model = ODEsolver()
model.add(Dense(15, activation='tanh', input_shape=(1,)))
model.add(Dense(15, activation='tanh'))
model.add(Dense(15, activation='tanh'))
model.add(Dense(15, activation='tanh'))
model.add(Dense(15, activation='tanh'))
model.add(Dense(15, activation='tanh'))
model.add(Dense(15, activation='tanh'))
model.add(Dense(15, activation='tanh'))
model.add(Dense(15, activation='tanh'))
model.add(Dense(15, activation='tanh'))
model.add(Dense(15, activation='tanh'))
model.add(Dense(15, activation='tanh'))
model.add(Dense(15, activation='tanh'))
model.add(Dense(15, activation='tanh'))
model.add(Dense(15, activation='tanh'))

model.add(Dense(1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "od_esolver_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_48 (Dense)                │ (None, 15)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_50 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_54 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_56 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_58 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_59 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_60 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_61 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_62 (Dense)                │ (None, 15)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_63 (Dense)                │ (None, 1)              │            16 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,406 (13.30 KB)
#  Trainable params: 3,406 (13.30 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer=RMSprop(), metrics=['loss'])

x = tf.linspace(0, 3, 350)  # Ajusta el rango de tiempo
history = model.fit(x, epochs=350, verbose=1)

x_testv = tf.linspace(0,3, 350)  # Ajusta el rango de tiempo
a = model.predict(x_testv)
# Out:
# Epoch 1/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - loss: 1.0247
# Epoch 2/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9923
# Epoch 3/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9925
# Epoch 4/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9899
# Epoch 5/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9935
# Epoch 6/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9907
# Epoch 7/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0022
# Epoch 8/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9952
# Epoch 9/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.9944
# Epoch 10/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.9913
# Epoch 11/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.0029
# Epoch 12/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9957
# Epoch 13/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9937
# Epoch 14/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9955
# Epoch 15/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9959
# Epoch 16/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9939
# Epoch 17/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9925
# Epoch 18/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.9996
# Epoch 19/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9943
# Epoch 20/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9938
# Epoch 21/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9960
# Epoch 22/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9967
# Epoch 23/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9923
# Epoch 24/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9932
# Epoch 25/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9921
# Epoch 26/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9907
# Epoch 27/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9926
# Epoch 28/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9913
# Epoch 29/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9918
# Epoch 30/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9940
# Epoch 31/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9937
# Epoch 32/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9944
# Epoch 33/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9918
# Epoch 34/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9937
# Epoch 35/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9950
# Epoch 36/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9999
# Epoch 37/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9949
# Epoch 38/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9952
# Epoch 39/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9970
# Epoch 40/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9886
# Epoch 41/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0044
# Epoch 42/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0006
# Epoch 43/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9977
# Epoch 44/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9911
# Epoch 45/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9963
# Epoch 46/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9959
# Epoch 47/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9917
# Epoch 48/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9933
# Epoch 49/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9975
# Epoch 50/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9907
# Epoch 51/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9907
# Epoch 52/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9946
# Epoch 53/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9950
# Epoch 54/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9991
# Epoch 55/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9925
# Epoch 56/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9969
# Epoch 57/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9982
# Epoch 58/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0043
# Epoch 59/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9946
# Epoch 60/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9909
# Epoch 61/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9901
# Epoch 62/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.0001
# Epoch 63/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9990
# Epoch 64/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9942
# Epoch 65/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9888
# Epoch 66/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0038
# Epoch 67/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0030
# Epoch 68/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9934
# Epoch 69/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9944
# Epoch 70/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9909
# Epoch 71/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9973
# Epoch 72/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9955
# Epoch 73/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9908
# Epoch 74/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9921
# Epoch 75/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9909
# Epoch 76/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9937
# Epoch 77/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9932
# Epoch 78/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9934
# Epoch 79/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9956
# Epoch 80/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9938
# Epoch 81/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9961
# Epoch 82/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9932
# Epoch 83/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9941
# Epoch 84/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9896
# Epoch 85/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9941
# Epoch 86/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9918
# Epoch 87/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0023
# Epoch 88/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9949
# Epoch 89/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9901
# Epoch 90/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0016
# Epoch 91/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9936
# Epoch 92/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.0027
# Epoch 93/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9935
# Epoch 94/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9900
# Epoch 95/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9913
# Epoch 96/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9921
# Epoch 97/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0008
# Epoch 98/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9974
# Epoch 99/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9943
# Epoch 100/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9956
# Epoch 101/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9931
# Epoch 102/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9906
# Epoch 103/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9904
# Epoch 104/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9897
# Epoch 105/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9924
# Epoch 106/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9942
# Epoch 107/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9902
# Epoch 108/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9932
# Epoch 109/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9945
# Epoch 110/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9943
# Epoch 111/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.9954
# Epoch 112/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9888
# Epoch 113/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9927
# Epoch 114/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9953
# Epoch 115/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9962
# Epoch 116/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9953
# Epoch 117/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9893
# Epoch 118/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9927
# Epoch 119/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.9955
# Epoch 120/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.9944
# Epoch 121/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9915
# Epoch 122/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9883
# Epoch 123/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9979
# Epoch 124/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9935
# Epoch 125/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9940
# Epoch 126/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9954
# Epoch 127/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9936
# Epoch 128/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9951
# Epoch 129/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9933
# Epoch 130/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9918
# Epoch 131/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9902
# Epoch 132/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9923
# Epoch 133/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9909
# Epoch 134/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9911
# Epoch 135/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9939
# Epoch 136/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9928
# Epoch 137/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9939
# Epoch 138/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9931
# Epoch 139/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9937
# Epoch 140/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9913
# Epoch 141/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9908
# Epoch 142/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9984
# Epoch 143/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9928
# Epoch 144/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9952
# Epoch 145/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9915
# Epoch 146/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9917
# Epoch 147/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9914
# Epoch 148/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9923
# Epoch 149/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9963
# Epoch 150/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.9942
# Epoch 151/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9938
# Epoch 152/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9924
# Epoch 153/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9945
# Epoch 154/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9940
# Epoch 155/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9891
# Epoch 156/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9925
# Epoch 157/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9881
# Epoch 158/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9900
# Epoch 159/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9875
# Epoch 160/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9887
# Epoch 161/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9945
# Epoch 162/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9887
# Epoch 163/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9923
# Epoch 164/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9895
# Epoch 165/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9935
# Epoch 166/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9902
# Epoch 167/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9907
# Epoch 168/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9915
# Epoch 169/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9890
# Epoch 170/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9943
# Epoch 171/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9988
# Epoch 172/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9943
# Epoch 173/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9989
# Epoch 174/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9919
# Epoch 175/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9971
# Epoch 176/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9913
# Epoch 177/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9925
# Epoch 178/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9906
# Epoch 179/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9927
# Epoch 180/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9920
# Epoch 181/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9998
# Epoch 182/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9947
# Epoch 183/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9926
# Epoch 184/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9910
# Epoch 185/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9949
# Epoch 186/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9928
# Epoch 187/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.9948
# Epoch 188/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9949
# Epoch 189/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9963
# Epoch 190/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9876
# Epoch 191/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9970
# Epoch 192/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9932
# Epoch 193/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9965
# Epoch 194/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9874
# Epoch 195/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9926
# Epoch 196/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9908
# Epoch 197/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9897
# Epoch 198/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9920
# Epoch 199/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9917
# Epoch 200/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9940
# Epoch 201/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9934
# Epoch 202/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9884
# Epoch 203/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9907
# Epoch 204/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9932
# Epoch 205/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9870
# Epoch 206/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9928
# Epoch 207/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.9867
# Epoch 208/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9998
# Epoch 209/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9956
# Epoch 210/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9878
# Epoch 211/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9867
# Epoch 212/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9908
# Epoch 213/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9915
# Epoch 214/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9896
# Epoch 215/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9933
# Epoch 216/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9914
# Epoch 217/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9917
# Epoch 218/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9959
# Epoch 219/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.9940
# Epoch 220/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9890
# Epoch 221/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.9951
# Epoch 222/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9855
# Epoch 223/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9957
# Epoch 224/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9968
# Epoch 225/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9983
# Epoch 226/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.9926
# Epoch 227/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9906
# Epoch 228/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9988
# Epoch 229/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9946
# Epoch 230/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9887
# Epoch 231/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9888
# Epoch 232/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9967
# Epoch 233/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9952
# Epoch 234/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9954
# Epoch 235/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9935
# Epoch 236/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9877
# Epoch 237/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.9878
# Epoch 238/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9871
# Epoch 239/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9914
# Epoch 240/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9929
# Epoch 241/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9885
# Epoch 242/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.9876
# Epoch 243/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9927
# Epoch 244/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9921
# Epoch 245/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9977
# Epoch 246/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9922
# Epoch 247/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9915
# Epoch 248/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9958
# Epoch 249/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9932
# Epoch 250/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9971
# Epoch 251/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9943
# Epoch 252/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9935
# Epoch 253/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9926
# Epoch 254/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9922
# Epoch 255/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9929
# Epoch 256/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9890
# Epoch 257/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9965
# Epoch 258/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9935
# Epoch 259/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9931
# Epoch 260/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9891
# Epoch 261/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9944
# Epoch 262/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9902
# Epoch 263/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9899
# Epoch 264/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9922
# Epoch 265/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9929
# Epoch 266/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9943
# Epoch 267/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9974
# Epoch 268/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9883
# Epoch 269/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9941
# Epoch 270/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9906
# Epoch 271/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9927
# Epoch 272/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9898
# Epoch 273/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9893
# Epoch 274/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9850
# Epoch 275/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9971
# Epoch 276/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9899
# Epoch 277/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.9909
# Epoch 278/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9877
# Epoch 279/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9862
# Epoch 280/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9941
# Epoch 281/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9921
# Epoch 282/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9904
# Epoch 283/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9894
# Epoch 284/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9955
# Epoch 285/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9889
# Epoch 286/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9900
# Epoch 287/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9917
# Epoch 288/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.9952
# Epoch 289/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9943
# Epoch 290/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9915
# Epoch 291/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9916
# Epoch 292/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.9951
# Epoch 293/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9914
# Epoch 294/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9880
# Epoch 295/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9961
# Epoch 296/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9882
# Epoch 297/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9899
# Epoch 298/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9989
# Epoch 299/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9995
# Epoch 300/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9952
# Epoch 301/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9895
# Epoch 302/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9974
# Epoch 303/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9868
# Epoch 304/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9970
# Epoch 305/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9931
# Epoch 306/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9864
# Epoch 307/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9940
# Epoch 308/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9913
# Epoch 309/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9934
# Epoch 310/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9895
# Epoch 311/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9870
# Epoch 312/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9884
# Epoch 313/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9918
# Epoch 314/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9875
# Epoch 315/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9991
# Epoch 316/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9958
# Epoch 317/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9922
# Epoch 318/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9897
# Epoch 319/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9963
# Epoch 320/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9906
# Epoch 321/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9980
# Epoch 322/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9915
# Epoch 323/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.9897
# Epoch 324/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9938
# Epoch 325/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.9903
# Epoch 326/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9865
# Epoch 327/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0041
# Epoch 328/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9924
# Epoch 329/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9915
# Epoch 330/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9967
# Epoch 331/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9943
# Epoch 332/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9925
# Epoch 333/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9960
# Epoch 334/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9962
# Epoch 335/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.9904
# Epoch 336/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9909
# Epoch 337/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9874
# Epoch 338/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9877
# Epoch 339/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9858
# Epoch 340/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9911
# Epoch 341/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9915
# Epoch 342/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9916
# Epoch 343/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9917
# Epoch 344/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9912
# Epoch 345/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9870
# Epoch 346/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9919
# Epoch 347/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9875
# Epoch 348/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9893
# Epoch 349/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9913
# Epoch 350/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9911
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step

# %%
plt.plot(x_testv, a, color='red')
plt.plot(x_testv, np.e**(-x/20)*(np.cos(np.sqrt(100)*x)+(np.sin(np.sqrt(100)*x)/20* np.sqrt(100))), color='green')
plt.show()

# %% [markdown]
# En este codigo me surge el problema de que aunque el error es bajo, la grafica no es nada parecida
